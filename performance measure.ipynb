# %%
import pandas as pd

# %%
df=pd.read_csv('runtimes.csv', sep=',', index_col=0)
df
# Out:
#       SingleLinkedList  DoubleLinkedList
# N
# 1000          7.141669          0.127979
# 1001          6.927229          0.183650
# 1002          7.108546          0.104188
# 1003          5.916298          0.044319
# 1004          7.179301          0.038565
# 1005          5.806668          0.024569
# 1006          6.908569          0.030168
# 1007          6.928784          0.028924
# 1008          6.848233          0.038254
# 1009          6.339269          0.026125
# 1010          6.102436          0.024880
# 1011          5.912877          0.033744
# 1012          7.694485          0.022859
# 1013          5.330204          0.023014
# 1014          5.397849          0.023792
# 1015          5.532826          0.026125
# 1016          6.062006          0.036699
# 1017          6.422930          0.032189
# 1018          7.904104          0.023481
# 1019          5.502036          0.031101
# 1020          7.051165          0.041364
# 1021          7.706769          0.047584
# ...

# %%
import matplotlib.pylab as plt 
# %matplotlib inline
ax = df.plot(secondary_y = ['DoubleLinkedList'])
ax.set_ylabel("ms")
